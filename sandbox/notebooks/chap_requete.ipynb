# %%
#!pip install pandas
#!pip install elasticsearch # elasticsearch==8.11.0 si pb de version

# %%
from elasticsearch import Elasticsearch, helpers
import json 
bulk = helpers.bulk # Insertion de masse 

es = Elasticsearch("http://elasticsearch:9200")  # connexion au server es depuis Jupyter

# %%
docs = [
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "To be, or not to be: that is the question."
    },
    {
        "play_name": "Macbeth",
        "speaker": "LADY MACBETH",
        "text_entry": "Out, damned spot! out, I say!"
    },
    {
        "play_name": "Othello",
        "speaker": "OTHELLO",
        "text_entry": "She loved me for the dangers I had passed."
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "Being or not being"
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "I am and I will be"
    },
    {
        "play_name": "Macbeth",
        "speaker": "MACBETH",
        "text_entry": "To be king is everything"
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "To be, or not to be: that is the question."
    },
    {
        "play_name": "Macbeth",
        "speaker": "LADY MACBETH",
        "text_entry": "Out, damned spot! out, I say!"
    },
    {
        "play_name": "Othello",
        "speaker": "OTHELLO",
        "text_entry": "She loved me for the dangers I had passed."
    },
    {
        "play_name": "Macbeth",
        "speaker": "MACBETH",
        "text_entry": "Tomorrow, and tomorrow, and tomorrow.",
        "year": 1606
    },
    {
        "play_name": "King Lear",
        "speaker": "KING LEAR",
        "text_entry": "Blow, winds, and crack your cheeks!",
        "year": 1605
    },
    {
        "play_name": "Julius Caesar",
        "speaker": "MARK ANTONY",
        "text_entry": "Friends, Romans, countrymen, lend me your ears.",
        "year": 1599
    },
    {
        "play_name": "Romeo and Juliet",
        "speaker": "ROMEO",
        "text_entry": "It is the east, and Juliet is the sun.",
        "year": 1595
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "The time is out of joint.",
        "year": 1601
    },
    {
        "play_name": "Othello",
        "speaker": "IAGO",
        "text_entry": "I am not what I am.",
        "year": 1604
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "To be or not to be",
        "year": 1603
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "The time is out of joint",
        "year": 1601
    },
    {
        "play_name": "Othello",
        "speaker": "OTHELLO",
        "text_entry": "She loved me for the dangers I had passed",
        "year": 1604
    },
    {
        "play_name": "Othello",
        "speaker": "IAGO",
        "text_entry": "I am not what I am",
        "year": 1604
    },
    {
        "play_name": "Macbeth",
        "speaker": "MACBETH",
        "text_entry": "Tomorrow and tomorrow and tomorrow",
        "year": 1606
    },
    {
        "play_name": "Macbeth",
        "speaker": "LADY MACBETH",
        "text_entry": "Out damned spot",
        "year": 1606
    },
    {
        "play_name": "King Lear",
        "speaker": "KING LEAR",
        "text_entry": "Blow winds and crack your cheeks",
        "year": 1605
    },
    {
        "play_name": "Romeo and Juliet",
        "speaker": "ROMEO",
        "text_entry": "Juliet is the sun",
        "year": 1595
    },
    {
        "play_name": "Hamlet",
        "speaker": "HAMLET",
        "text_entry": "Love makes us weak",
        "year": 1603
    },
    {
        "play_name": "Othello",
        "speaker": "OTHELLO",
        "text_entry": "I know this love is true",
        "year": 1604
    },
    {
        "play_name": "Macbeth",
        "speaker": "MACBETH",
        "text_entry": "Tomorrow and tomorrow",
        "year": 1606
    },
    {
        "play_name": "Romeo and Juliet",
        "speaker": "ROMEO",
        "text_entry": "Juliet is the sun",
        "year": 1595
    }
]

# %%
# ingestion des données 
actions = [
    {
        "_index": "shakespeare", # index == db 
        "_source": doc
    }
    for doc in docs
]

if es.indices.exists(index="shakespeare"):
    es.indices.delete(index="shakespeare")
else:
    es.indices.create(index="shakespeare")

success, errors = bulk(es, actions, refresh=True)

print("Documents indexés :", success)
print("Erreurs :", errors)
# Out:
# Documents indexés : 27
# Erreurs : []

# %%
res = es.search(
     index="shakespeare",
     query={"match_all": {}}
)

# json.dumps permet d'indenter le code correction
# print( json.dumps(res["hits"]["hits"], indent=2) )

# %%
# création d'un autre index
docs = [
{
  "play_name": "Hamlet",
  "speaker": "HAMLET",
  "text_entry": "To be, or not to be: that is the question."
},
{
  "play_name": "Macbeth",
  "speaker": "LADY MACBETH",
  "text_entry": "Out, damned spot! out, I say!"
},
{
  "play_name": "Othello",
  "speaker": "OTHELLO",
  "text_entry": "She loved me for the dangers I had passed."
}
]

actions = [
    {
        "_index": "shakespeare_v2",
        "_source": doc
    }
    for doc in docs
]

if es.indices.exists(index="shakespeare_v2"):
    es.indices.delete(index="shakespeare_v2")
else:
    es.indices.create(index="shakespeare_v2")

success, errors = bulk(es, actions, refresh=True)

print("Documents indexés :", success)
print("Erreurs :", errors)
# Out:
# Documents indexés : 3
# Erreurs : []

# %%
res = es.search(
     index="shakespeare_v2",
     query={"match_all": {}}
)

data = res["hits"]["hits"]

# %%
import pandas as pd 

dataClean = [ d["_source"] for d in data ]
dataClean

df = pd.DataFrame(dataClean)

# %%
df
# Out:
#   play_name       speaker                                  text_entry
# 0    Hamlet        HAMLET  To be, or not to be: that is the question.
# 1   Macbeth  LADY MACBETH               Out, damned spot! out, I say!
# 2   Othello       OTHELLO  She loved me for the dangers I had passed.

# %%
res = es.search(
     index="shakespeare",
     query={"match": {"text_entry" : "be" }}  # recherche par token
)

# res["hits"]["hits"]

# %%
# une recheche range requete structurée pas de full-text → pas de score pertinent, tout est à 1 
query_range = {
    "query": {
        "range": {
            "year": {
                "gte": 1603,
                "lte": 1606
            }
        }
    }
}

res = es.search(index="shakespeare", body=query_range)

#for hit in res["hits"]["hits"]:
#    print(hit["_score"], hit["_source"])

# %%
# requete imbriquée 

"""
pas de score pour cette partie de la requête 
{"term": {"play_name.keyword": "Hamlet"}}
{"range": {"year": {"gte": 1601}}}


ici Elasticsearch calcule un score 
{"match": {"text_entry": "love"}}
{"match": {"text_entry": "time"}}

"""

query = {
    "query": {
        "bool": {
            "must": [
                {"term": {"play_name.keyword": "Hamlet"}},
                {"range": {"year": {"gte": 1601}}},
                {
                    "bool": {
                        "should": [
                            {"match": {"text_entry": "love"}},
                            {"match": {"text_entry": "time"}}
                        ],
                        "minimum_should_match": 1
                    }
                }
            ]
        }
    }
}

"""
(play_name = Hamlet) AND (year >= 1601) AND (match love OU match time) 
"""

res = es.search(index="shakespeare", body=query)

for hit in res["hits"]["hits"]:
    print(hit["_score"], hit["_source"])
# Out:
# 5.0109615 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'Love makes us weak', 'year': 1603}
# 4.632104 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'The time is out of joint.', 'year': 1601}
# 4.632104 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'The time is out of joint', 'year': 1601}

# %%
if False:
    doc = {
      "speaker": "HAMLET",
      "play_name": "Hamlet",
      "year": 1605,
      "text_entry": "love is everywhere"
    }
    res = es.index(
        index="shakespeare",
        document=doc
    )
    
    print(res)


"""
- filtre = A AND B
- score = amélioré si C ou D match avec "minimum_should_match": 0

ce document sort par exemple

{
  "speaker": "HAMLET",
  "play_name": "Hamlet",
  "year": 1605,
  "text_entry": "love is everywhere"
}

"""

query = {
    "query": {
        "bool": {
            "must": [
                {"term": {"play_name.keyword": "Hamlet"}},
                {
                    "range": {
                        "year": {
                            "gte": 1601
                        }
                    }
                }
            ],
            "should": [
                {"match": {"text_entry": "love"}},
                {"match": {"text_entry": "time"}}
            ],
            "minimum_should_match": 0
        }
    }
}

res = es.search(index="shakespeare", body=query)

for hit in res["hits"]["hits"]:
    print(hit["_score"], hit["_source"])
# Out:
# {'_index': 'shakespeare', '_id': 'Jf7daJ0BaVpLwIWk8Xe9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# 4.9852533 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'Love makes us weak', 'year': 1603}
# 4.2607927 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'The time is out of joint.', 'year': 1601}
# 4.2607927 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'The time is out of joint', 'year': 1601}
# 4.0081105 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'Time is out of joint, O cursed spite!', 'year': 1602}
# 2.116004 {'play_name': 'Hamlet', 'speaker': 'HAMLET', 'text_entry': 'To be or not to be', 'year': 1603}

# %%
# Et cette histoire de token 
response = es.indices.analyze(
    body={
        "analyzer": "standard",
        "text": "The time is out of joint."
    }
)

for token in response["tokens"]:
    print(token["token"])
# Out:
# the
# time
# is
# out
# of
# joint

# %%
query = {
    "query": {
        "match" : { "text_entry" : "the" }
    }
}

res = es.search(index="shakespeare", body=query)
res["hits"]["hits"]
# Out:
# [{'_index': 'shakespeare',
#   '_id': 'Ff5jZ50BaVpLwIWk13d1',
#   '_score': 1.193002,
#   '_source': {'play_name': 'Romeo and Juliet',
#    'speaker': 'ROMEO',
#    'text_entry': 'It is the east, and Juliet is the sun.',
#    'year': 1595}},
#  {'_index': 'shakespeare',
#   '_id': 'H_5jZ50BaVpLwIWk13d1',
#   '_score': 1.1444051,
#   '_source': {'play_name': 'Romeo and Juliet',
#    'speaker': 'ROMEO',
#    'text_entry': 'Juliet is the sun',
#    'year': 1595}},
#  {'_index': 'shakespeare',
#   '_id': 'I_5jZ50BaVpLwIWk13d1',
#   '_score': 1.1444051,
#   '_source': {'play_name': 'Romeo and Juliet',
#    'speaker': 'ROMEO',
#    'text_entry': 'Juliet is the sun',
#    'year': 1595}},
#  {'_index': 'shakespeare',
#   '_id': 'Fv5jZ50BaVpLwIWk13d1',
#   '_score': 0.990594,
#   '_source': {'play_name': 'Hamlet',
#    'speaker': 'HAMLET',
#    'text_entry': 'The time is out of joint.',
#    'year': 1601}},
#  {'_index': 'shakespeare',
#   '_id': 'Gf5jZ50BaVpLwIWk13d1',
#   '_score': 0.990594,
#   '_source': {'play_name': 'Hamlet',
#    'speaker': 'HAMLET',
#    'text_entry': 'The time is out of joint',
#    'year': 1601}},
#  {'_index': 'shakespeare',
#   '_id': 'C_5jZ50BaVpLwIWk13d1',
#   '_score': 0.82439315,
#   '_source': {'play_name': 'Othello',
#    'speaker': 'OTHELLO',
#    'text_entry': 'She loved me for the dangers I had passed.'}},
#  {'_index': 'shakespeare',
#   '_id': 'Ef5jZ50BaVpLwIWk13d1',
#   '_score': 0.82439315,
#   '_source': {'play_name': 'Othello',
#    'speaker': 'OTHELLO',
#    'text_entry': 'She loved me for the dangers I had passed.'}},
#  {'_index': 'shakespeare',
#   '_id': 'Gv5jZ50BaVpLwIWk13d1',
#   '_score': 0.82439315,
#   '_source': {'play_name': 'Othello',
#    'speaker': 'OTHELLO',
#    'text_entry': 'She loved me for the dangers I had passed',
#    'year': 1604}},
#  {'_index': 'shakespeare',
#   '_id': 'Cf5jZ50BaVpLwIWk13d1',
#   '_score': 0.7807298,
#   '_source': {'play_name': 'Hamlet',
#    'speaker': 'HAMLET',
#    'text_entry': 'To be, or not to be: that is the question.'}},
#  {'_index': 'shakespeare',
#   '_id': 'D_5jZ50BaVpLwIWk13d1',
#   '_score': 0.7807298,
#   '_source': {'play_name': 'Hamlet',
#    'speaker': 'HAMLET',
#    'text_entry': 'To be, or not to be: that is the question.'}}]
